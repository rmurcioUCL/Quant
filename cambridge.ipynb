# %%
import pandas as pd
import matplotlib.pyplot as plts
import seaborn as sns
import matplotlib as plt
df1 = pd.read_csv("D:\quant-master\Demo2\model-runs\dis_roads_min.csv",header=None)
df2 = pd.read_csv("D:\quant-master\Demo2\model-runs\dis_bus_min.csv",header=None)
df3 = pd.read_csv("D:\quant-master\Demo2\model-runs\dis_rail_min.csv",header=None)

plts.subplot(2,2,1)
plts.title('Roads')
sns.heatmap(df1,cmap='GnBu')

plts.subplot(2,2,2)
plts.title('Bus')
sns.heatmap(df2,cmap='GnBu')

plts.subplot(2,2,3)
plts.title('Train')
sns.heatmap(df3,cmap='GnBu')


#plt.rcParams['figure.figsize']=(20,15)

# %%
import numpy as np
#df = pd.read_csv("D:\quant-master\Demo2\model-runs\dis_rail_min.csv",header=None)
dfObs = pd.read_csv("D:\quant-master\Demo2\model-runs\TObs.csv",header=None)

# %%
import seaborn as sns
import matplotlib as plt
plt.rcParams['figure.figsize']=(20,15)
#df1=df[df!=0]
#print(df1.head())
sns.heatmap(dfObs,cmap='GnBu')

# %%
dfPred = pd.read_csv("D:\quant-master\Demo2\model-runs\TPred.csv",header=None)
plt.rcParams['figure.figsize']=(20,15)
sns.heatmap(dfPred,cmap='GnBu')

# %%
dferror=abs(dfObs-dfPred)
dferror.head()
plt.rcParams['figure.figsize']=(20,15)
sns.heatmap(dferror,cmap='GnBu')

# %%
import matplotlib.pyplot as plts

df1 = pd.read_csv("D:\quant-master\Demo2\model-runs\TPred_Q3_1.csv",header=None)
df2 = pd.read_csv("D:\quant-master\Demo2\model-runs\TPred_Q3_2.csv",header=None)
df3 = pd.read_csv("D:\quant-master\Demo2\model-runs\TPred_Q3_3.csv",header=None)

plts.subplot(2,2,1)
plts.title('TPred')
sns.heatmap(df,cmap='GnBu')

plts.subplot(2,2,2)
plts.title('TPred_Roads')
sns.heatmap(df1,cmap='GnBu')

plts.subplot(2,2,3)
plts.title('TPred2_Bus')
sns.heatmap(df2,cmap='GnBu')

plts.subplot(2,2,4)
plts.title('TPred3_Train')
sns.heatmap(df3,cmap='GnBu')
#plt.rcParams['figure.figsize']=(20,15)
